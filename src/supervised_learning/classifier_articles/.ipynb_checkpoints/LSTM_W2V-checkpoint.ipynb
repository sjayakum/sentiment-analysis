# %%
import pickle
from nltk.corpus import movie_reviews
import numpy as np
np.random.seed(1337)  # for reproducibility

from keras.preprocessing import sequence
from keras.utils import np_utils
from keras.models import Sequential
from keras.layers.core import Dense, Dropout, Activation
from keras.layers.embeddings import Embedding
from keras.layers.recurrent import LSTM
from keras.datasets import imdb
import numpy as np
w2v_corpus = pickle.load(open('full_corpus_w2v.p','rb'))

negids = movie_reviews.fileids('neg')
posids = movie_reviews.fileids('pos')


neg = []
pos = []

# %%
import numpy as np
temp = movie_reviews.sents(negids[0])
negtemp = []
print temp
for each_sentence in temp:
    print "SENTENCE!"
    print each_sentence
    val = np.zeros((100,1))
    for each_word in each_sentence:
        print "WORD!"
        print each_word
        vec_each_word = np.array(w2v_corpus[each_word]) # this will be 100*1 list
        val = [  (val[k] + vec_each_word[k])  for k in range(100) ]
        print vec_each_word
        print val
    
    
print negtemp
# Out:
# [[u'plot', u':', u'two', u'teen', u'couples', u'go', u'to', u'a', u'church', u'party', u',', u'drink', u'and', u'then', u'drive', u'.'], [u'they', u'get', u'into', u'an', u'accident', u'.'], ...]
# [ 9.48450953]
# 0.294534
# [ 9.77904335]
# [ 6.2625497]
# 0.294534
# [ 6.55708352]
# [ 22.412598]
# 0.294534
# [ 22.70713182]
# [ 7.21999088]
# 0.549841
# [ 7.76983228]
# [ 12.45261391]
# 0.294534
# [ 12.74714772]
# [ 0.29453382]
# 0.294534
# [ 0.58906764]
# [ 0.29453382]
# 0.294534
# [ 0.58906764]
# [ 32.6301561]
# 0.294534
# [ 32.92468992]
# [ 64.29597747]
# 0.294534
# [ 64.59051129]
# [ 19.5054689]
# 0.294534
# [ 19.80000272]
# [ 14.63444941]
# 0.549841
# [ 15.18429081]
# [ 20.45682406]
# 0.294534
# [ 20.75135788]
# [ 34.96243659]
# 0.294534
# [ 35.25697041]
# [ 85.15317935]
# 0.294534
# [ 85.44771317]
# [ 69.7167607]
# 0.294534
# [ 70.01129452]
# [ 33.44482887]
# 0.294534
# [ 33.73936269]
# [ 18.81486119]
# 0.549841
# [ 19.3647026]
# [ 4.04761013]
# 0.294534
# [ 4.34214395]
# [ 86.45724957]
# 0.294534
# [ 86.75178339]
# [ 57.23949723]
# 0.294534
# [ 57.53403105]
# [ 26.65755354]
# 0.508066
# [ 27.16561906]
# [ 0.50806552]
# 0.508066
# [ 1.01613104]
# [ 8.64118901]
# 0.294534
# [ 8.93572283]
# [ 0.29453382]
# 0.294534
# [ 0.58906764]
# [ 0.29453382]
# 0.294534
# [ 0.58906764]
# [ 24.29021457]
# 0.294534
# [ 24.58474839]
# [ 20.00649825]
# 0.549841
# [ 20.55633965]
# [ 17.97445997]
# 0.549841
# [ 18.52430137]
# [ 25.23252487]
# 0.294534
# [ 25.52705869]
# [ 47.7778026]
# 0.294534
# [ 48.07233642]
# [ 50.01951475]
# 0.294534
# [ 50.31404857]
# [ 33.10475082]
# 0.294534
# [ 33.39928464]
# [ 52.03772013]
# 0.294534
# [ 52.33225394]
# [ 25.68651125]
# 0.294534
# [ 25.98104507]
# [ 0.29453382]
# 0.294534
# [ 0.58906764]
# [ 0.29453382]
# 0.294534
# [ 0.58906764]
# [ 31.94733302]
# 0.294534
# [ 32.24186683]
# [ 24.42288008]
# 0.294534
# [ 24.7174139]
# [ 0.66826642]
# 0.294534
# [ 0.96280023]
# [ 0.29453382]
# 0.294534
# [ 0.58906764]
# [ 0.29453382]
# 0.294534
# [ 0.58906764]
# [ 4.39690968]
# 0.508066
# [ 4.90497521]
# [ 5.17630231]
# 0.549841
# [ 5.72614372]
# [ 70.09051304]
# -0.068968
# [ 70.02154505]
# [[array([ 9.48450953]), array([ 12.4756097]), array([-7.4179545]), array([-1.8658845]), array([-6.32108791]), array([-0.97381926]), array([ 6.09288666]), array([-13.02985902]), array([ 3.37143998]), array([ 4.92088344]), array([-2.39259801]), array([-0.49554411]), array([-7.40279519]), array([-5.71789174]), array([-1.85935165]), array([ 3.85876707]), array([ 3.42748536]), array([-3.81331727]), array([ 3.91852696]), array([-6.02833994]), array([-9.64165536]), array([-4.49430888]), array([ 5.05984599]), array([ 6.23606476]), array([ 8.47952788]), array([-4.65385912]), array([-3.22252297]), array([ 2.88103629]), array([ 3.75244573]), array([-8.67347348]), array([-6.92342393]), array([ 9.35501003]), array([-14.59314657]), array([ 5.94602022]), array([-2.72535018]), array([ 10.01034178]), array([-3.48256046]), array([ 1.46565955]), array([ 2.78323962]), array([-12.26187152]), array([-4.7438306]), array([-3.29603642]), array([-5.664496]), array([-8.45859426]), array([ 2.28219611]), array([-2.67327101]), array([-0.5092379]), array([-2.34084181]), array([-3.13120531]), array([ 3.6021922]), array([-5.97024952]), array([-4.46614734]), array([ 2.11147242]), array([-2.22522185]), array([-1.93873231]), array([ 4.54345734]), array([ 0.19880145]), array([-2.43656291]), array([-6.14361079]), array([-6.25164607]), array([-5.13994588]), array([ 9.17235544]), array([ 4.15555882]), array([ 2.42824703]), array([ 8.29864812]), array([-9.2711917]), array([-2.04711166]), array([ 5.86645343]), array([ 0.613133]), array([-4.70914793]), array([-2.02673146]), array([-6.89795046]), array([-17.761115]), array([ 0.24953911]), array([-8.25740203]), array([ 3.20727656]), array([ 1.95218651]), array([ 7.40792878]), array([ 9.22057028]), array([ 10.94582647]), array([ 0.22490145]), array([ 4.82148203]), array([-0.16064643]), array([-11.49538903]), array([ 0.32223894]), array([-9.87929332]), array([ 1.86451044]), array([-2.02342699]), array([-5.93846489]), array([-3.22728966]), array([-9.25706705]), array([ 0.01967629]), array([-0.77679878]), array([-4.30174801]), array([ 0.3789484]), array([-10.2629365]), array([-1.18443263]), array([ 4.47538274]), array([-3.45367079]), array([-5.70662562])], [array([ 6.2625497]), array([ 7.99636686]), array([-3.38501348]), array([ 3.21583994]), array([-3.27005534]), array([-0.16137522]), array([ 0.8569505]), array([-9.48123808]), array([ 4.53085022]), array([ 2.4586007]), array([-1.15136122]), array([-3.0895535]), array([-6.45224716]), array([-3.17711402]), array([-0.97649166]), array([ 2.70353173]), array([ 3.33168978]), array([ 0.57789808]), array([ 4.12162128]), array([-3.74135563]), array([-3.15026827]), array([-1.82747754]), array([-0.36979447]), array([ 3.84650885]), array([-0.11201764]), array([-0.81081712]), array([-2.28732657]), array([ 1.15973172]), array([-0.34937872]), array([ 0.39344448]), array([-2.83323792]), array([ 2.64655453]), array([-6.48983055]), array([ 2.81395368]), array([ 0.22033137]), array([ 5.16753646]), array([-2.57026172]), array([-1.5095024]), array([-2.0486552]), array([-5.50023174]), array([-4.05341008]), array([ 3.65830269]), array([-5.7752196]), array([-2.33959062]), array([-1.98901176]), array([-1.96795797]), array([-0.19614653]), array([ 1.74851619]), array([-1.2753535]), array([ 2.96107584]), array([-4.31207979]), array([-1.46679173]), array([ 1.6313031]), array([-2.46844622]), array([-1.45578585]), array([-2.86950053]), array([ 1.52584672]), array([-1.29628325]), array([-2.06366907]), array([-1.67098079]), array([-2.86417663]), array([ 5.20939365]), array([ 3.58678506]), array([ 0.93424193]), array([ 6.17590751]), array([-3.73750362]), array([-0.60438818]), array([-0.40033802]), array([ 1.85419112]), array([ 0.44107166]), array([ 0.7472595]), array([-2.38232015]), array([-8.36163493]), array([ 2.83004824]), array([-8.25016591]), array([ 1.51151409]), array([-2.64026879]), array([ 2.39482294]), array([ 5.1521202]), array([ 0.77976374]), array([-0.42806977]), array([ 4.49614348]), array([-3 ...

# %%
for i in negids:

    temp = movie_reviews.sents(i)
    negtemp = []
    for each_sentence in temp:
        val = [0]*100
        for each_word in each_sentence:
            vec_each_word = w2v_corpus[each_word]
            val = [ val[k] + vec_each_word[k] for k in range(100)]
        negtemp.append(val)
    neg.append(negtemp)




for i in posids:

    temp = movie_reviews.sents(i)
    postemp = []
    for each_sentence in temp:
        val = [0]*100
        for each_word in each_sentence:
            vec_each_word = w2v_corpus[each_word]
            val = [ val[k] + vec_each_word[k] for k in range(100)]
        postemp.append(val)
    pos.append(postemp)

print len(neg)
print len(pos)
print neg[0]
print neg[0][0]
