# %%
import pickle
from nltk.corpus import movie_reviews
import numpy as np
np.random.seed(1337)  # for reproducibility

from keras.preprocessing import sequence
from keras.utils import np_utils
from keras.models import Sequential
from keras.layers.core import Dense, Dropout, Activation
from keras.layers.embeddings import Embedding
from keras.layers.recurrent import LSTM
from keras.datasets import imdb
import numpy as np
w2v_corpus = pickle.load(open('full_corpus_w2v.p','rb'))

negids = movie_reviews.fileids('neg')
posids = movie_reviews.fileids('pos')


neg = []
pos = []

# %%
import numpy as np
temp = movie_reviews.sents(negids[0])
negtemp = []
print temp
for each_sentence in temp:
    print "SENTENCE!"
    print each_sentence
    val = np.zeros((100,1))
    for each_word in each_sentence:
        print "WORD!"
        print each_word
        vec_each_word = np.array(w2v_corpus[each_word]) # this will be 100*1 list
        val = [  (val[k] + vec_each_word[k])  for k in range(100) ]
        print vec_each_word
        print val
    
    
print negtemp
# Out:
# [[u'plot', u':', u'two', u'teen', u'couples', u'go', u'to', u'a', u'church', u'party', u',', u'drink', u'and', u'then', u'drive', u'.'], [u'they', u'get', u'into', u'an', u'accident', u'.'], ...]
# SENTENCE!
# [u'plot', u':', u'two', u'teen', u'couples', u'go', u'to', u'a', u'church', u'party', u',', u'drink', u'and', u'then', u'drive', u'.']
# WORD!
# plot
# [ 1.19715154  0.93241692 -1.19672585 -0.73496461  1.79815757 -2.08307648
#  -0.61910892  0.20738004  0.49979669  1.9129802  -1.28472888 -0.65418935
#   0.72317278 -1.02526665 -1.70784748  0.79813528 -0.70199585 -1.18262744
#  -0.17519903  0.35510918  1.21081686 -0.04642379 -0.20120518  0.65688825
#  -0.00553057 -1.3928901   0.10152186  1.17176461  2.18184805 -1.61750877
#  -1.56859183  1.45009637 -1.72849989 -0.15340219  0.04424655  1.60512733
#  -0.77195305  1.78745174  1.15636659 -0.64496946  0.21942505  0.28189346
#   0.10230749 -1.49579334  0.00533999 -1.87464786  0.92426187 -0.04380152
# ...

# %%
for i in negids:

    temp = movie_reviews.sents(i)
    negtemp = []
    for each_sentence in temp:
        val = [0]*100
        for each_word in each_sentence:
            vec_each_word = w2v_corpus[each_word]
            val = [ val[k] + vec_each_word[k] for k in range(100)]
        negtemp.append(val)
    neg.append(negtemp)




for i in posids:

    temp = movie_reviews.sents(i)
    postemp = []
    for each_sentence in temp:
        val = [0]*100
        for each_word in each_sentence:
            vec_each_word = w2v_corpus[each_word]
            val = [ val[k] + vec_each_word[k] for k in range(100)]
        postemp.append(val)
    pos.append(postemp)

print len(neg)
print len(pos)
print neg[0]
print neg[0][0]
